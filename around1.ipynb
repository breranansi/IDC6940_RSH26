# %% [markdown]
# This is a PySR run on the molecular mass dataset with the logarithm and exponential operators added. Iterations at 100. Box-Cox Transform.

# %%
# Install libraries
# %pip install -U pysr
# Out:
# Requirement already satisfied: pysr in /usr/local/lib/python3.11/dist-packages (1.5.9)
# Requirement already satisfied: click<9.0.0,>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (8.2.1)
# Requirement already satisfied: juliacall<0.9.27,>=0.9.24 in /usr/local/lib/python3.11/dist-packages (from pysr) (0.9.26)
# Requirement already satisfied: numpy<3.0.0,>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (2.0.2)
# Requirement already satisfied: pandas<3.0.0,>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (2.2.2)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (1.6.1)
# Requirement already satisfied: sympy<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (1.13.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pysr) (4.14.1)
# Requirement already satisfied: juliapkg<0.2,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from juliacall<0.9.27,>=0.9.24->pysr) (0.1.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=0.21.0->pysr) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2.0.0,>=1.0.0->pysr) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy<2.0.0,>=1.0.0->pysr) (1.3.0)
# Requirement already satisfied: filelock<4.0,>=3.16 in /usr/local/lib/python3.11/dist-packages (from juliapkg<0.2,>=0.1.17->juliacall<0.9.27,>=0.9.24->pysr) (3.18.0)
# Requirement already satisfied: semver<4.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from juliapkg<0.2,>=0.1.17->juliacall<0.9.27,>=0.9.24->pysr) (3.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=0.21.0->pysr) (1.17.0)

# %%
# Call Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
from pysr import PySRRegressor
import time
from scipy import stats
import sympy as sym
from scipy.stats import shapiro
from scipy.stats import kstest
import statsmodels.api as sm

# %%
# Colab
drive.mount('/content/drive')
df=pd.read_csv('/content/drive/MyDrive/goossens_raw.csv')
# Positron
#df=pd.read_csv('./goossens_raw.csv')
# Quarto
#df=pd.read_csv('./c694/goossens_raw.csv')


y=df['MW']
x=df[['SG','TBP']]
y_bc,bc=stats.boxcox(y)
print(bc)
# Out:
# Mounted at /content/drive
# -0.36241569290615483

# %%
v=np.linspace(y.min(),y.max())
v_bc=((np.pow(v,bc)-1.0)/bc)
v_ln=np.log(v)
v_sq=1/np.sqrt(v)

plt.scatter(v,v_bc,c="lightblue",edgecolors="darkblue", label="Box-Cox")
plt.scatter(v,v_ln,c="lightgreen",edgecolors="darkgreen", label="Logarithm",marker="s")
plt.scatter(v,v_sq,c="red",edgecolors="darkred", label="inverse-square-root",marker="v")
plt.title("Transform Comparison")
plt.xlabel("Molecular Mass")
plt.ylabel("Transformed Molecular Mass")
plt.grid()
plt.legend()
plt.show()

# %%
# Build Reverse Box-Cox Transform
def unBox(zee,lam):
    # zee = transformed variable
    # lam = box-cox parameter
    if (lam  != 0.0):
        return np.pow((lam*zee+1.0),(1.0/lam))
    else:
        return np.exp(zee)

# Build Forward Box-Cox Transform
def reBox(why,lam):
    # why = untransformed variable
    # lam = box-cox parameter
    if (lam  != 0.0):
        return (np.pow(why,lam)-1.0)/lam
    else:
        return np.log(why)

# %%
plt.hist(y_bc,edgecolor="black")
plt.xlabel("Transformed Molecular Mass")
plt.ylabel("Frequency")
plt.show()

# %%
t0 = time.time()
# Add Log and Exp Functions
myMod=PySRRegressor(
    random_state=7,
    deterministic=True,
    parallelism='serial',
#myMod=PySRRegressor(
    binary_operators=["+","-","*","/"],
    unary_operators=["exp","log"],
    niterations=100)
myMod.fit(x,y_bc)
print("time to fit: ",time.time() - t0, 'seconds')
y_pred=myMod.predict(x)
# Out:
# /usr/local/lib/python3.11/dist-packages/pysr/sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# INFO:pysr.sr:Compiling Julia backend...
# [ Info: Started!
# Expressions evaluated per second: 7.770e+04
# Progress: 420 / 3100 total iterations (13.548%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           1.014e-02  4.135e-02  y = log(SG + 9.6369)
# 5           3.849e-04  3.271e+00  y = (TBP * 0.00054649) + 2.036
# 6           2.094e-04  6.087e-01  y = (log(TBP) * 0.31332) + 0.37705
# 8           2.012e-04  1.990e-02  y = (log(TBP) * 0.39938) + (SG * -0.19553)
# 10          2.140e-05  1.121e+00  y = 0.2705 + ((0.34934 * log(TBP)) + (SG * -0.14202))
# 18          1.977e-05  9.895e-03  y = ((SG * -0.31873) + (log(TBP) * ((SG * 0.027215) + 0.32...
#                                       931))) + ((TBP * -4.5549e-07) + 0.40055)
# 21          1.960e-05  2.888e-03  y = ((TBP * -4.1541e-05) + (log(TBP) * (((log(TBP) * (SG *...
#                                        0.009169)) + 0.34625) + (SG * -0.08143)))) + 0.31804
# 23          1.753e-05  5.577e-02  y = ((log(TBP) * (((SG * -0.0061649) * log(TBP)) + 0.39252...
#                                       )) + ((TBP * -0.00011331) + (SG * (TBP * 0.00017957)))) + ...
#                                       0.063151
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.440e+04
# Progress: 960 / 3100 total iterations (30.968%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.1355)
# 6           1.970e-04  8.650e-03  y = log(TBP + 86.095) * 0.36429
# 8           1.947e-04  5.967e-03  y = (log(TBP - -151.54) * 0.40307) - 0.29127
# 9           4.998e-05  1.360e+00  y = log(TBP) * ((log(SG) * -0.026304) + 0.36865)
# 10          2.140e-05  8.484e-01  y = 0.2705 + ((0.34934 * log(TBP)) + (SG * -0.14202))
# 12          2.140e-05  4.590e-06  y = ((log(TBP + 0.018834) * 0.34935) + 0.27042) + (SG * -0...
#                                       .14202)
# 13          2.129e-05  5.081e-03  y = (0.35265 * log(TBP + log(TBP))) + (0.24525 + (SG * -0....
#                                       14188))
# 14          1.969e-05  7.809e-02  y = ((SG * -0.31512) + 0.40582) + (((SG * 0.026912) + 0.32...
#                                       821) * log(TBP))
# 15          1.657e-05  1.722e-01  y = (((SG * -0.046345) + ((log(SG) * TBP) * 3.4669e-05)) +...
#                                        0.4155) * log(TBP)
# 17          1.594e-05  1.955e-02  y = (log(TBP) * (((SG * -0.041297) + 0.40444) + ((TBP * 2....
#                                       8007e-05) * log(SG)))) + 0.039131
# 19          1.593e-05  1.064e-04  y = (log(TBP) * (((((TBP - -2.198) * 2.8007e-05) * log(SG)...
#                                       ) + (SG * -0.041359)) + 0.4045)) + 0.039169
# 20          1.593e-05  2.706e-05  y = (log(TBP) * (((SG * -0.041278) + 0.40442) + (log(SG) *...
#                                        ((TBP - log(SG)) * 2.7982e-05)))) + 0.039139
# 21          1.593e-05  1.726e-04  y = ((((TBP - (-2.3952 / SG)) * (2.7944e-05 * log(SG))) + ...
#                                       ((-0.041278 * SG) + 0.40442)) * log(TBP)) + 0.039139
# 22          1.592e-05  8.850e-04  y = ((((SG * -0.0437) + 0.40477) + (log(SG) * (((TBP - log...
#                                       (SG)) * 2.6815e-05) + 0.0032629))) * log(TBP)) + 0.052855
# 24          1.576e-05  4.973e-03  y = (((((TBP - (-2.3952 / log(SG / 0.60557))) * 2.7944e-05...
#                                       ) * log(SG)) + ((-0.041278 * SG) + 0.40442)) * log(TBP)) +...
#                                        0.039139
# 25          1.498e-05  5.084e-02  y = ((log(TBP + (SG * (TBP * 0.12331))) + TBP) - TBP) * ((...
#                                       (((TBP * 4.2467e-05) + -0.057776) * SG) * log(SG)) + 0.362...
#                                       67)
# 27          1.497e-05  2.480e-04  y = ((log(SG) * (((TBP * 4.2467e-05) + -0.057776) * SG)) +...
#                                        0.36267) * ((log(TBP + (SG * ((TBP + -0.51919) * 0.12331)...
#                                       )) + TBP) - TBP)
# 29          1.497e-05  1.291e-04  y = (((((TBP * 4.2467e-05) + -0.057776) * SG) * log(SG)) +...
#                                        0.36267) * ((log(TBP + (SG * ((TBP + (-0.69106 * 1.6952))...
#                                        * 0.12331))) + TBP) - TBP)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 8.960e+04
# Progress: 1532 / 3100 total iterations (49.419%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.13551)
# 6           1.970e-04  8.532e-03  y = log(TBP + 86.095) * 0.36429
# 8           6.812e-05  5.310e-01  y = ((SG * -0.028732) + 0.39761) * log(TBP)
# 9           3.740e-05  5.995e-01  y = ((log(SG) * -0.43114) + log(TBP)) * 0.3687
# 10          2.140e-05  5.585e-01  y = 0.2705 + ((0.34934 * log(TBP)) + (SG * -0.14202))
# 12          2.123e-05  3.881e-03  y = (log(TBP + 10.798) * 0.35631) + ((SG * -0.14106) + 0.2...
#                                       1835)
# 14          1.969e-05  3.771e-02  y = ((SG * -0.31512) + 0.40582) + (((SG * 0.026912) + 0.32...
#                                       821) * log(TBP))
# 15          1.657e-05  1.722e-01  y = log(TBP) * (((SG * -0.046338) + ((TBP * log(SG)) * 3.4...
#                                       654e-05)) + 0.41549)
# 17          1.594e-05  1.955e-02  y = (log(TBP) * (((SG * -0.041297) + 0.40444) + ((TBP * 2....
#                                       8007e-05) * log(SG)))) + 0.039131
# 19          1.460e-05  4.372e-02  y = (((log(SG) * ((TBP * 3.915e-05) + -0.049635)) * SG) + ...
#                                       0.36436) * log(TBP + (TBP * 0.087688))
# 21          1.460e-05  1.300e-04  y = ((((TBP * 3.8502e-05) + -0.049083) * (SG * log(SG))) +...
#                                        0.36326) * log(TBP + ((TBP * 0.11129) - 1.0178))
# 23          1.454e-05  2.012e-03  y = ((((TBP * 3.9596e-05) + -0.051721) * (((TBP * -0.00011...
#                                       265) + SG) * log(SG))) + 0.36439) * log(TBP + (TBP * 0.087...
#                                       594))
# 27          1.454e-05  9.163e-05  y = log(((TBP - (-0.65318 - 0.89571)) * 0.087594) + TBP) *...
#                                        ((((TBP * 3.9596e-05) + -0.051721) * (((TBP * -0.00011265...
#                                       ) + SG) * log(SG))) + 0.36439)
# 29          1.454e-05  4.441e-06  y = log(TBP + ((TBP - ((0.030496 - SG) - 0.89571)) * 0.087...
#                                       594)) * ((((TBP * 3.9596e-05) + -0.051721) * ((SG + (TBP *...
#                                        -0.00011265)) * log(SG))) + 0.36439)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.060e+04
# Progress: 2043 / 3100 total iterations (65.903%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.13551)
# 6           1.970e-04  8.532e-03  y = log(TBP + 86.095) * 0.36429
# 8           6.812e-05  5.310e-01  y = ((SG * -0.028732) + 0.39761) * log(TBP)
# 9           3.740e-05  5.995e-01  y = (log(SG) * -0.15884) + (log(TBP) * 0.3687)
# 10          2.140e-05  5.585e-01  y = 0.2705 + ((0.34934 * log(TBP)) + (SG * -0.14202))
# 12          2.123e-05  3.899e-03  y = ((log(TBP + 11.186) * 0.35654) + (SG * -0.1411)) + 0.2...
#                                       1668
# 14          1.969e-05  3.769e-02  y = ((SG * -0.31512) + 0.40582) + (((SG * 0.026912) + 0.32...
#                                       821) * log(TBP))
# 15          1.510e-05  2.655e-01  y = ((SG * (((TBP * 4.5275e-05) + -0.05463) * log(SG))) + ...
#                                       0.36901) * log(TBP)
# 17          1.471e-05  1.285e-02  y = ((((TBP * 4.0523e-05) + -0.050937) * (SG * log(SG))) +...
#                                        0.36864) * log(TBP + 4.8149)
# 19          1.460e-05  3.810e-03  y = (((log(SG) * ((TBP * 3.8626e-05) + -0.049201)) * SG) +...
#                                        0.36396) * log((0.095695 * TBP) + TBP)
# 21          1.460e-05  2.408e-04  y = ((((TBP * 3.8987e-05) + -0.049421) * (SG * log(SG))) +...
#                                        0.36295) * log(((TBP * 0.11922) - 2.1438) + TBP)
# 23          1.453e-05  2.192e-03  y = log(TBP + (TBP * 0.087706)) * (((log(SG) * ((TBP * 3.9...
#                                       98e-05) + -0.052178)) * ((TBP * -0.00012837) + SG)) + 0.36...
#                                       44)
# 24          1.402e-05  3.605e-02  y = ((log(SG) * (SG * (-0.048698 + (TBP * 3.8011e-05)))) +...
#                                        0.36346) * log(((TBP - (0.50282 / log(SG))) * 0.10579) + ...
#                                       TBP)
# 26          1.393e-05  3.124e-03  y = (((log(SG) * ((TBP * 3.9408e-05) + -0.049736)) * SG) +...
#                                        0.36351) * log(((TBP - (0.56896 / log(SG))) * 0.10584) + ...
#                                       (TBP + -1.4009))
# 27          1.393e-05  2.369e-04  y = ((log(SG) * (SG * ((3.9408e-05 * TBP) + -0.049736))) +...
#                                        0.36351) * log(((TBP - (log(1.6114) / log(SG))) * 0.10584...
#                                       ) + (TBP + -1.4009))
# 28          1.392e-05  2.001e-04  y = (((((TBP * 3.9408e-05) + -0.049736) * SG) * log(SG)) +...
#                                        0.36351) * log((((TBP - ((-0.33986 / -0.62971) / log(SG))...
#                                       ) * 0.10584) + TBP) + -1.4009)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.380e+04
# Progress: 2548 / 3100 total iterations (82.194%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.13551)
# 6           1.970e-04  8.532e-03  y = log(TBP + 86.095) * 0.36429
# 8           6.812e-05  5.310e-01  y = ((SG * -0.028732) + 0.39761) * log(TBP)
# 9           3.740e-05  5.995e-01  y = (log(SG) * -0.15884) + (log(TBP) * 0.3687)
# 10          2.140e-05  5.585e-01  y = ((log(TBP) * 0.34934) + (SG * -0.14203)) + 0.27048
# 12          2.123e-05  3.949e-03  y = ((SG * -0.14089) + 0.20747) + (log(TBP + 13.017) * 0.3...
#                                       5777)
# 14          1.964e-05  3.877e-02  y = ((log(TBP) * ((SG * 0.02969) + 0.32602)) + 0.41988) + ...
#                                       (SG * -0.33299)
# 15          1.510e-05  2.633e-01  y = ((SG * (((TBP * 4.5275e-05) + -0.05463) * log(SG))) + ...
#                                       0.36901) * log(TBP)
# 17          1.460e-05  1.670e-02  y = ((((log(SG) * ((TBP * 3.9402e-05) + -0.050063)) * SG) ...
#                                       + 0.36403) * log(TBP)) - -0.032764
# 21          1.460e-05  1.004e-04  y = ((((TBP * 3.8987e-05) + -0.049421) * (SG * log(SG))) +...
#                                        0.36295) * log(((TBP * 0.11922) - 2.1438) + TBP)
# 23          1.453e-05  2.192e-03  y = log(TBP + (TBP * 0.087706)) * (((log(SG) * ((TBP * 3.9...
#                                       98e-05) + -0.052178)) * ((TBP * -0.00012837) + SG)) + 0.36...
#                                       44)
# 24          1.402e-05  3.605e-02  y = ((log(SG) * (SG * (-0.048698 + (TBP * 3.8011e-05)))) +...
#                                        0.36346) * log(((TBP - (0.50282 / log(SG))) * 0.10579) + ...
#                                       TBP)
# 26          1.392e-05  3.457e-03  y = ((log(SG) * (((3.9947e-05 * TBP) + -0.050174) * SG)) +...
#                                        0.36375) * log(((TBP - (0.52767 / log(SG))) * 0.1014) + (...
#                                       -1.7482 + TBP))
# 28          1.392e-05  6.557e-05  y = (((log(SG) * ((TBP * 4.0007e-05) + -0.050213)) * SG) +...
#                                        0.36375) * log((TBP + ((TBP - (0.58004 / log(log(exp(SG))...
#                                       ))) * 0.10141)) + -1.7482)
# 30          1.392e-05  1.145e-04  y = ((log(SG) * (SG * ((3.9947e-05 * TBP) + -0.050174))) +...
#                                        0.36375) * log((TBP + -1.7482) + (((TBP - -0.78707) - (0....
#                                       52767 / log(log(exp(SG))))) * 0.1014))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 9.020e+04
# Progress: 2952 / 3100 total iterations (95.226%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.13551)
# 6           1.970e-04  8.532e-03  y = log(TBP + 86.095) * 0.36429
# 8           4.744e-05  7.120e-01  y = log(TBP) * ((0.02281 / SG) + 0.34581)
# 9           3.740e-05  2.376e-01  y = (log(SG) * -0.15884) + (log(TBP) * 0.3687)
# 10          2.140e-05  5.585e-01  y = ((log(TBP) * 0.34934) + (SG * -0.14203)) + 0.27048
# 12          2.123e-05  3.949e-03  y = ((SG * -0.14089) + 0.20747) + (log(TBP + 13.017) * 0.3...
#                                       5777)
# 14          1.964e-05  3.877e-02  y = ((SG * -0.33299) + 0.41988) + (((SG * 0.029684) + 0.32...
#                                       602) * log(TBP))
# 15          1.510e-05  2.633e-01  y = ((SG * (((TBP * 4.5275e-05) + -0.05463) * log(SG))) + ...
#                                       0.36901) * log(TBP)
# 17          1.460e-05  1.670e-02  y = ((((log(SG) * ((TBP * 3.9402e-05) + -0.050063)) * SG) ...
#                                       + 0.36403) * log(TBP)) - -0.032764
# 19          1.460e-05  5.662e-07  y = (log(TBP) * ((log(SG) * (((TBP * SG) * 3.9402e-05) + (...
#                                       SG * -0.050063))) + 0.36403)) - -0.032764
# 20          1.424e-05  2.493e-02  y = log(TBP + (-0.053804 / log(SG))) * (((SG * log(SG)) * ...
#                                       ((TBP * 4.5483e-05) + -0.054747)) + 0.36897)
# 24          1.402e-05  3.977e-03  y = ((log(SG) * (SG * (-0.048698 + (TBP * 3.8011e-05)))) +...
#                                        0.36346) * log(((TBP - (0.50282 / log(SG))) * 0.10579) + ...
#                                       TBP)
# 26          1.392e-05  3.654e-03  y = ((log(SG) * (((TBP * 4.0007e-05) + -0.050213) * SG)) +...
#                                        0.36375) * log(TBP + (((TBP - (0.5281 / log(SG))) * 0.101...
#                                       41) + -1.7482))
# 28          1.391e-05  9.239e-06  y = ((SG * (((TBP * 3.9916e-05) + -0.050146) * log(SG))) +...
#                                        0.36375) * log(((((TBP - -0.78707) - (0.52767 / log(SG)))...
#                                        * 0.10141) + TBP) + -1.7482)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           1.148e-02  0.000e+00  y = 2.3504
# 4           6.197e-04  9.730e-01  y = log(TBP) * 0.37301
# 5           1.987e-04  1.137e+00  y = exp(log(TBP) * 0.13551)
# 6           1.970e-04  8.532e-03  y = log(TBP + 86.095) * 0.36429
# 8           4.744e-05  7.120e-01  y = log(TBP) * ((0.02281 / SG) + 0.34581)
# 9           3.740e-05  2.376e-01  y = (log(SG) * -0.15884) + (log(TBP) * 0.3687)
# 10          2.140e-05  5.585e-01  y = ((log(TBP) * 0.34934) + (SG * -0.14203)) + 0.27048
# 12          2.123e-05  3.949e-03  y = ((SG * -0.14089) + 0.20747) + (log(TBP + 13.017) * 0.3...
#                                       5777)
# 14          1.964e-05  3.877e-02  y = (SG * -0.33299) + (0.41988 + (((SG * 0.029684) + 0.326...
#                                       02) * log(TBP)))
# 15          1.510e-05  2.633e-01  y = ((SG * (((TBP * 4.5275e-05) + -0.05463) * log(SG))) + ...
#                                       0.36901) * log(TBP)
# 17          1.460e-05  1.670e-02  y = ((((log(SG) * ((TBP * 3.9402e-05) + -0.050063)) * SG) ...
#                                       + 0.36403) * log(TBP)) - -0.032764
# 19          1.460e-05  5.662e-07  y = (log(TBP) * ((log(SG) * (((TBP * SG) * 3.9402e-05) + (...
#                                       SG * -0.050063))) + 0.36403)) - -0.032764
# 20          1.424e-05  2.493e-02  y = log(TBP + (-0.053804 / log(SG))) * (((SG * log(SG)) * ...
#                                       ((TBP * 4.5483e-05) + -0.054747)) + 0.36897)
# 22          1.424e-05  1.816e-04  y = ((SG * (log(SG) * ((TBP * 4.5416e-05) + -0.054692))) -...
#                                        -0.36897) * log(((-0.053818 / SG) / log(SG)) + TBP)
# 24          1.402e-05  7.773e-03  y = ((log(SG) * (SG * (-0.048698 + (TBP * 3.8011e-05)))) +...
#                                        0.36346) * log(((TBP - (0.50282 / log(SG))) * 0.10579) + ...
#                                       TBP)
# 26          1.391e-05  3.663e-03  y = ((((3.9993e-05 * TBP) + -0.050212) * (log(SG) * SG)) +...
#                                        0.36375) * log(TBP + (((TBP - (0.5281 / log(SG))) * 0.101...
#                                       41) + -1.7482))
# 28          1.391e-05  2.682e-07  y = ((SG * (((TBP * 3.9916e-05) + -0.050146) * log(SG))) +...
#                                        0.36375) * log(((((TBP - -0.78707) - (0.52767 / log(SG)))...
#                                        * 0.10141) + TBP) + -1.7482)
# 30          1.391e-05  2.936e-05  y = ((((TBP * 3.9993e-05) + -0.050212) * (log(SG) * SG)) +...
#                                        0.36375) * log((TBP + (((SG - 0.60607) + (TBP - (0.5281 /...
#                                        log(SG)))) * 0.10141)) + -1.7482)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# time to fit:  60.768468379974365 seconds
#   - outputs/20250731_150421_k0nrYf/hall_of_fame.csv

# %%
# Fit plot
plt.plot(y_bc,y_pred,marker="o",linestyle="None")
plt.xlabel('Box-Cox Molecular Mass')
plt.ylabel('Predicted Box-Cox Molecular Mass')
plt.title('Molecular Mass vs Predicted Molecular Mass')
plt.grid()
plt.show()

# %%
# Pull Out Equation
myEq=myMod.sympy()
# Print (Old) Equation before clean-up
print(myEq)
# Out:
# (SG*(4.5274992e-5*TBP - 0.054629795)*log(SG) + 0.36901343)*log(TBP)

# %%
# Clean-Up Equation
sym.simplify(myEq)
# Out:
# (SG*(4.5274992e-5*TBP - 0.054629795)*log(SG) + 0.36901343)*log(TBP)

# %%
# Calculate  Residuals
ydel=y_pred-y_bc
print("Minimum",ydel.min())
print("Maximum",ydel.max())
print("Average",ydel.mean())
print("Median",np.median(ydel))
# Out:
# Minimum -0.010359957524449737
# Maximum 0.013075734342925749
# Average -1.6483135152047168e-05
# Median -0.000324815962935876

# %%
# Raw Residuals Plot
plt.plot(y_bc,ydel,marker="o",linestyle="None")
plt.xlabel('Box-Cox Molecular Mass')
plt.ylabel('Box-Cox Residuals')
plt.title('Residuals')
plt.grid()
plt.show()

# %%
# Normality Test #1
plt.hist(ydel,edgecolor="black")
plt.title("Box-Cox Residuals")
plt.xlabel("Residual Error")
plt.ylabel("Frequency")
plt.show()

# %%
# Normality Test #2
fig = sm.qqplot(ydel, line='45')
plt.xlabel("Theoretical Quantiles (Normal)")
plt.ylabel("Sample Quantiles")
plt.grid()
plt.show()

# %%
# Normality Test #3
shapiro(ydel)
# Out:
# ShapiroResult(statistic=np.float64(0.9655009252747575), pvalue=np.float64(0.05075056014211319))

# %%
# Normality Test #4
kstest(ydel,'norm')
# Out:
# KstestResult(statistic=np.float64(0.4958670488511923), pvalue=np.float64(2.0164035288708485e-16), statistic_location=np.float64(-0.010359957524449737), statistic_sign=np.int8(-1))

# %%
# Reverse Transform on Predicted Values
y_unt=unBox(y_pred,bc)
print("Minimum",y_unt.min())
print("Maximum",y_unt.max())
print("Average",y_unt.mean())
print("Median",np.median(y_unt))
# Out:
# Minimum 74.18572575373912
# Maximum 1451.8586308287918
# Average 302.44788743808454
# Median 220.6880556910935

# %%
# Fit plot
plt.plot(y,y_unt,marker="o",linestyle="None")
plt.xlabel('Apparent Molecular Mass')
plt.ylabel('Predicted Molecular Mass')
plt.title('Untransformed vs. Original Molecular Mass')
plt.grid()
plt.show()

# %%
ydelunt=y_unt-y
# Untransformed Residuals Plot
plt.plot(y,ydelunt,marker="o",linestyle="None")
plt.xlabel('Raw Molecular Mass')
plt.ylabel('Raw Residuals')
plt.title('Residuals')
plt.grid()
plt.show()

# %%
# Normality Test #1
plt.hist(ydelunt,edgecolor="black")
plt.title("Box-Cox Residuals")
plt.xlabel("Residual Error")
plt.ylabel("Frequency")
plt.show()

# %%
# Normality Test #2
fig = sm.qqplot(ydelunt, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Sample Quantiles")
plt.grid()
plt.show()

# %%
# Add New Predictions to training Dataframe
df['Fit_Mw']=y_unt
#Calculate Correlation Coefficient between columns
df.corr()
# Out:
#               SG       TBP        MW    Fit_Mw
# SG      1.000000  0.625218  0.334852  0.354662
# TBP     0.625218  1.000000  0.869591  0.894181
# MW      0.334852  0.869591  1.000000  0.995895
# Fit_Mw  0.354662  0.894181  0.995895  1.000000

# %%
# Load Hosseinifar dataset
# Colab
#drive.mount('/content/drive')
dfh=pd.read_csv('/content/drive/MyDrive/hosseinifar_raw.csv')
# Positron
#dfh=pd.read_csv('./hosseinifar_raw.csv')
# Quarto
#df=pd.read_csv('./c694/hosseinifar_raw.csv')

yh=dfh['MW']
yhbc=reBox(yh,bc)
xh=dfh[['SG','TBP']]

# %%
# Generate testing Predictions
y_h1=unBox(myMod.predict(xh),bc)

# %%
# Add Predictions to testing Dataframe
dfh['Fit_Mw']=y_h1
# Calculate Correlation Coefficient between columns
dfh.corr()
# Out:
#               SG       TBP        MW    Fit_Mw
# SG      1.000000  0.985561  0.954145  0.946584
# TBP     0.985561  1.000000  0.990235  0.986523
# MW      0.954145  0.990235  1.000000  0.999696
# Fit_Mw  0.946584  0.986523  0.999696  1.000000
